# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1. Load the dataset 
col_names = ["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","the_predicted_attribute"]
df = pd.read_csv('processed.cleveland.data', header=None, names = col_names)

# %%
#2.Print the dataset
pd.DataFrame(df)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  the_predicted_attribute
# ...

# %%
#3.Print the 5 first lines of the dataset
df.head(5)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  the_predicted_attribute
# 0    3.0  0.0  6.0                        0
# 1    2.0  3.0  3.0                        2
# 2    2.0  2.0  7.0                        1
# 3    3.0  0.0  3.0                        0
# 4    1.0  0.0  3.0                        0

# %%
#4. Print the 5 last lines of the dataset
df.tail(5)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  the_predicted_attribute
# 298    2.0  0.0  7.0                        1
# 299    2.0  2.0  7.0                        2
# 300    2.0  1.0  7.0                        3
# 301    2.0  1.0  3.0                        1
# 302    1.0    ?  3.0                        0

# %%
#5. Check the type of the variables
print(df.dtypes)
#Change the type of qualitative variables to catogery
#(column 1,2,5,6,8,10,11,12,13)['sex','cp','fbs','restecg','exang','slope','ca','thal',the_predicted_attribute']
df['sex'] = df['sex'].astype('category')
df['cp'] = df['cp'].astype('category')
df['fbs'] = df['fbs'].astype('category')
df['restecg'] = df['restecg'].astype('category')
df['exang'] = df['exang'].astype('category')
df['slope'] = df['slope'].astype('category')
df['ca'] = df['ca'].astype('category')
df['thal'] = df['thal'].astype('category')
df['the_predicted_attribute'] = df['the_predicted_attribute'].astype('category')
# Out:
# age                        float64
# sex                        float64
# cp                         float64
# trestbps                   float64
# chol                       float64
# fbs                        float64
# restecg                    float64
# thalach                    float64
# exang                      float64
# oldpeak                    float64
# slope                      float64
# ca                          object
# thal                        object
# the_predicted_attribute      int64
# dtype: object

# %%
#6. Check if you have nan values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      303 non-null    float64
#  1   sex                      303 non-null    category
#  2   cp                       303 non-null    category
#  3   trestbps                 303 non-null    float64
#  4   chol                     303 non-null    float64
#  5   fbs                      303 non-null    category
#  6   restecg                  303 non-null    category
#  7   thalach                  303 non-null    float64
#  8   exang                    303 non-null    category
#  9   oldpeak                  303 non-null    float64
#  10  slope                    303 non-null    category
#  11  ca                       303 non-null    category
#  12  thal                     303 non-null    category
# ...

# %%
#7. Apply a solution for the nan values
#1) Replace the missing value by the average value.
#E.g.
df["age"] = df["age"].fillna(df["age"].mean())

before_del = pd.DataFrame(df)
print(before_del)
#2) Delete the column is there are too much Nan values in certain column.
#E.g.
del df['age']
after_del = pd.DataFrame(df)
print(after_del)
#We can see from the result that: "Column 0" is being deleted.

#3) Delete the row if there are not too much Nan values in certain column.
df = df.drop([0])
print(pd.DataFrame(df))
#We can see from the result that: "Row 0" is being deleted.
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  the_predicted_attribute
# ...

# %%
#8. Statistics of quantitative variables (describe)
df[["age","trestbps",'chol','thalach','oldpeak']].describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944  131.689769  246.693069  149.607261    1.039604
# std      9.038662   17.599748   51.776918   22.875003    1.161075
# min     29.000000   94.000000  126.000000   71.000000    0.000000
# 25%     48.000000  120.000000  211.000000  133.500000    0.000000
# 50%     56.000000  130.000000  241.000000  153.000000    0.800000
# 75%     61.000000  140.000000  275.000000  166.000000    1.600000
# max     77.000000  200.000000  564.000000  202.000000    6.200000

# %%
#9. Study every quantitative variables (histogram, plos)
#Quantitative variables(column 0,3,4,7,9)["age","trestbps",'chol','thalach','oldpeak']
#Histgram
plt.figure(figsize=(10,6))
plt.suptitle('Histgram')
plt.subplot(231)
plt.hist(df["age"], bins="auto")
plt.subplot(232)
plt.hist(df["trestbps"], bins="auto")
plt.subplot(233)
plt.hist(df["chol"], bins="auto")
plt.subplot(234)
plt.hist(df["thalach"], bins="auto")
plt.subplot(235)
plt.hist(df["oldpeak"], bins="auto")
plt.show()
#plot:
plt.figure(figsize=(10,6))
plt.suptitle('Plot')
plt.subplot(231)
plt.plot(df["age"])
plt.subplot(232)
plt.plot(df["trestbps"])
plt.subplot(233)
plt.plot(df["chol"])
plt.subplot(234)
plt.plot(df["thalach"])
plt.subplot(235)
plt.plot(df["oldpeak"])
plt.show()

# %%
#10. Study every qualitative variables (barplot)
#Qualitative variables(column 1,2,5,6,8,10,11,12,13)['sex','cp','fbs','restecg','exang','slope','ca','thal','the_predicted_attribute']
#bar:
plt.figure(figsize=(14,10))
plt.suptitle('Barplot')
plt.subplot(331)
df["sex"].value_counts().plot(kind='bar')
#We can see the number of male is twice as female.
plt.subplot(332)
df["cp"].value_counts().plot(kind='bar')
'''We can see the number of 4 is nearly twice the number of 3 which is nearly twice the number of 2 
and the number of 2 is nearly twice the number of 1 
-- Value 1: typical angina
-- Value 2: atypical angina
-- Value 3: non-anginal pain
-- Value 4: asymptomatic
'''
plt.subplot(333)
df["fbs"].value_counts().plot(kind='bar')
#(fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#We can see most the the people's fasting blood sugar is lower than 120 mg/dl
plt.subplot(334)
df["restecg"].value_counts().plot(kind='bar')
'''restecg: resting electrocardiographic results
-- Value 0: normal
-- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
-- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
We can see most the the people's resting electrocardiographic results are normal or value 2'''
plt.subplot(335)
df["exang"].value_counts().plot(kind='bar')
'''exang: exercise induced angina (1 = yes; 0 = no)
'''
plt.subplot(336)
df["slope"].value_counts().plot(kind='bar')
plt.subplot(337)
df["ca"].value_counts().plot(kind='bar')
plt.subplot(338)
df["thal"].value_counts().plot(kind='bar')
plt.subplot(339)
df["the_predicted_attribute"].value_counts().plot(kind='bar')
plt.show()

# %%
#11. Study the links between quantitatives variables (correlations, scatter, plot, metrics)
#Quantitative variables ((column 0,3,4,7,9)["age","trestbps",'chol','thalach','oldpeak']
corr = df[["age","trestbps",'chol','thalach','oldpeak']].corr()
#print out the correlations
print('The correlations:')
print(corr)
print('\n')
#Scatter:
plt.figure(figsize=(10,5))
plt.suptitle("Scatter plots")
plt.subplot(121)
plt.scatter(df['age'], df['trestbps'])
plt.subplot(122)
plt.scatter(df['chol'], df['thalach'])
plt.show()
print('\n')
#Plot:
plt.figure(figsize=(10,5))
plt.suptitle("Plots")
plt.subplot(121)
plt.scatter(df['age'], df['trestbps'])
plt.subplot(122)
plt.scatter(df['chol'], df['thalach'])
plt.show()
print('\n')
#Heatmap
plt.title("heatmap")
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# The correlations:
#                age  trestbps      chol   thalach   oldpeak
# age       1.000000  0.284946  0.208950 -0.393806  0.203805
# trestbps  0.284946  1.000000  0.130120 -0.045351  0.189171
# chol      0.208950  0.130120  1.000000 -0.003432  0.046564
# thalach  -0.393806 -0.045351 -0.003432  1.000000 -0.343085
# oldpeak   0.203805  0.189171  0.046564 -0.343085  1.000000

# %%
#12. Study the link between qualitative variables (chi-squared)
#Qualitative variables(column 1,2,5,6,8,10,11,12,13) ['sex','cp','fbs','restecg','exang','slope','ca','thal','the_predicted_attribute']
from scipy.stats import chi2_contingency
def chi2(c1, c2):
    table = pd.crosstab(df[c1],df[c2])
    stat, p, dof, expected = chi2_contingency(table)
    print("This is the result between:column{0} and column{1}".format(c1, c2))
    print('stat=%.3f, p=%.3f' % (stat, p))
    if p > 0.05:
        print('Probably independent')
    else:
        print('Probably dependent')
    print()

l = ['sex','cp','fbs','restecg','exang','slope','ca','thal','the_predicted_attribute']
for i,c1 in enumerate(l):
    for c2 in l[i+1:]:
        chi2(c1,c2)
# Out:
# This is the result between:columnsex and columncp
# stat=6.791, p=0.079
# Probably independent
#
# This is the result between:columnsex and columnfbs
# stat=0.436, p=0.509
# Probably independent
#
# This is the result between:columnsex and columnrestecg
# stat=3.585, p=0.167
# Probably independent
#
# This is the result between:columnsex and columnexang
# stat=5.826, p=0.016
# Probably dependent
#
# This is the result between:columnsex and columnslope
# stat=0.727, p=0.695
# Probably independent
#
# This is the result between:columnsex and columnca
# stat=7.635, p=0.106
# Probably independent
#
# This is the result between:columnsex and columnthal
# stat=45.854, p=0.000
# Probably dependent
#
# This is the result between:columnsex and columnthe_predicted_attribute
# stat=23.425, p=0.000
# Probably dependent
#
# This is the result between:columncp and columnfbs
# stat=4.067, p=0.254
# Probably independent
#
# This is the result between:columncp and columnrestecg
# stat=9.648, p=0.140
# ...

# %%
pip install statsmodels
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/Users/skyemalfoy/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
#13.Study the link between qualitative vs quantitative variables (ANOVA)
#Here we use an example between cp(chest pain type) and age:
import os
import random
import patsy
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.anova import AnovaRM
from statsmodels.regression.mixed_linear_model import MixedLMResults
from scipy import stats
# #Do cat_codes on variables:
# df['cp'] = df['cp'].cat.codes
# df['age'] = df['age'].cat.codes
# inspect data
sns.catplot(x='cp', y="age", data=df, dodge=True, kind='violin', aspect=3)
plt.title("ANOVA")
plt.show()

# generate model for linear regression
my_model = smf.ols(formula='age ~ cp', data=df)

# fit model to data to obtain parameter estimates
my_model_fit = my_model.fit()

# print summary of linear regression
print(my_model_fit.summary())

# show anova table
anova_table = sm.stats.anova_lm(my_model_fit, typ=2)
print(anova_table)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    age   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     3.300
# Date:                Thu, 19 May 2022   Prob (F-statistic):             0.0703
# Time:                        12:44:05   Log-Likelihood:                -1094.8
# No. Observations:                 303   AIC:                             2194.
# Df Residuals:                     301   BIC:                             2201.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     52.3229      1.275     41.053      0.000      49.815      54.831
# ...

# %%
#14. Is the dataset balanced ? For which variables
'''Conclusion: We can not find any variable that is balanced!!!!!!!!!!'''

plt.figure(figsize=(10,10))
plt.subplot(331)
df["age"].value_counts().plot(kind='bar')
plt.subplot(332)
df["sex"].value_counts().plot(kind='bar')
plt.subplot(333)
df["cp"].value_counts().plot(kind='bar')
plt.subplot(334)
df["trestbps"].value_counts().plot(kind='bar')
plt.subplot(335)
df["chol"].value_counts().plot(kind='bar')
plt.subplot(336)
df["fbs"].value_counts().plot(kind='bar')
plt.subplot(337)
df["restecg"].value_counts().plot(kind='bar')
plt.subplot(338)
df["thalach"].value_counts().plot(kind='bar')
plt.subplot(339)
df["exang"].value_counts().plot(kind='bar')
plt.show()
plt.figure(figsize=(10,5))
plt.subplot(231)
df["oldpeak"].value_counts().plot(kind='bar')
plt.subplot(232)
df["slope"].value_counts().plot(kind='bar')
plt.subplot(233)
df["ca"].value_counts().plot(kind='bar')
plt.subplot(234)
df["thal"].value_counts().plot(kind='bar')
plt.subplot(235)
df["the_predicted_attribute"].value_counts().plot(kind='bar')
plt.show()

# %%
#15. Study the variable num depending on groupby on qualitative variables
output = df['the_predicted_attribute'].groupby(df['sex']).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 #15. Study the variable num depending on groupby on qualitative variables
# ----> 2 output = df['the_predicted_attribute'].groupby(df['sex']).sum()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:2189, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2185 # If we are grouping on categoricals we want unobserved categories to
#    2186 # return zero, rather than the default of NaN which the reindexing in
#    2187 # _agg_general() returns. GH #31422
#    2188 with com.temp_setattr(self, "observed", True):
# -> 2189     result = self._agg_general(
#    2190         numeric_only=numeric_only,
#    2191         min_count=min_count,
#    2192         alias="add",
#    2193         npfunc=np.sum,
#    2194     )
# ...

# %%
#16. PCA on quantitative variables

# %%
#17. Apply one hot encoding
pd.get_dummies(df, columns = ['cp', 'slope'])
# Out:
#       age  sex  trestbps   chol  fbs restecg  thalach exang  oldpeak   ca  \
# 0    63.0  1.0     145.0  233.0  1.0     2.0    150.0   0.0      2.3  0.0
# 1    67.0  1.0     160.0  286.0  0.0     2.0    108.0   1.0      1.5  3.0
# 2    67.0  1.0     120.0  229.0  0.0     2.0    129.0   1.0      2.6  2.0
# 3    37.0  1.0     130.0  250.0  0.0     0.0    187.0   0.0      3.5  0.0
# 4    41.0  0.0     130.0  204.0  0.0     2.0    172.0   0.0      1.4  0.0
# ..    ...  ...       ...    ...  ...     ...      ...   ...      ...  ...
# 298  45.0  1.0     110.0  264.0  0.0     0.0    132.0   0.0      1.2  0.0
# 299  68.0  1.0     144.0  193.0  1.0     0.0    141.0   0.0      3.4  2.0
# 300  57.0  1.0     130.0  131.0  0.0     0.0    115.0   1.0      1.2  1.0
# 301  57.0  0.0     130.0  236.0  0.0     2.0    174.0   0.0      0.0  1.0
# 302  38.0  1.0     138.0  175.0  0.0     0.0    173.0   0.0      0.0    ?
#
#     thal the_predicted_attribute  cp_1.0  cp_2.0  cp_3.0  cp_4.0  slope_1.0  \
# ...

# %%
#18. PCA on all the variables

# %%
#19. Train linear model to predict chol with the age

# %%
#20. Train an extract tree classifier to predict num with all the variables
